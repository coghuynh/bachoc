# %%
# %%bash
#
# python3 src/run.py -data="/Users/huynhnguyen/WorkDir/bachoc_1/data/(16844277137145_29_06_2024_20_12)do-van-chien-1980-11-17-1719666757.txt" -triples_model=gemini-2.0-flash
# Out:
# ERROR! Session/line number was not unique in database. History logging moved to new session 118
#
#             Extract relational triples from the following text.
#             Return only the JSON array of triples (subject, predicate, object) as shown in the examples.
#
#             Text:
#             (Nội dung đúng ở ô nào thì đánh dấu vào ô đó: ; Nội dung không đúng thì để trống: □) Đối tượng đăng ký: Giảng viên □;
# Giảng viên thỉnh giảng:  Ngành: Y học;
# Chuyên ngành: Nội Tim Mạch A. THÔNG TIN CÁ NHÂN
# 1. Họ và tên người đăng ký: ĐỖ VĂN CHIẾN
# 2. Ngày tháng năm sinh: 17 - 11 - 1980;  Nam;  Quốc tịch: Việt Nam;
# Dân tộc: Kinh; Tôn giáo: Không có
# 3. Đảng viên Đảng Cộng sản Việt Nam:
# 
# 4. Quê quán (xã/phường, huyện/quận, tỉnh/thành phố):
# Hoằng Thắng, Hoằng Hóa, Thanh Hóa
# ...
